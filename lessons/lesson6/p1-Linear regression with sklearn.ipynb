# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris_train_set.csv')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                6.0               2.2                5.0               1.5
# 1                6.4               2.8                5.6               2.1
# 2                7.7               3.0                6.1               2.3
# 3                6.1               3.0                4.6               1.4
# 4                6.8               3.0                5.5               2.1
#
#    iris_type
# 0          2
# 1          2
# 2          2
# 3          1
# 4          2

# %%
X=df['petal length (cm)']
y=df['petal width (cm)']
sns.scatterplot(data=df,x='petal length (cm)',y='petal width (cm)')
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
X=df[['petal length (cm)']]
y=df['petal width (cm)']
reg.fit(X,y)

print ('w1=',reg.coef_[0])
print ('w0=',reg.intercept_)
# Out:
# w1= 0.4204654723848021
# w0= -0.3735253509729999

# %%
X_test=[[3]]
reg.predict(X_test)
# Out:
# c:\Users\moshe\miniconda3\envs\test1_phd\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.88787107])

# %%
sns.scatterplot(data=df,x='petal length (cm)',y='petal width (cm)');
range_x = [X.min(),X.max()]
plt.plot(range_x,reg.predict(range_x),color='red');
# Out:
# c:\Users\moshe\miniconda3\envs\test1_phd\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
sns.regplot(x=X,y=y);
